# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

from forecasting import load_daily_sales
from baseline_model import prepare_baseline_data

daily_sales = load_daily_sales()

daily_sales.head()
